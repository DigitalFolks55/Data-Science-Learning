# %% [markdown]
# # Data in Python

# %% [markdown]
# ## Overall

# %% [markdown]
# ## Numeric

# %% [markdown]
# ## String

# %% [markdown]
# ## List

# %% [markdown]
# ## Tuple

# %% [markdown]
# # Dictionary

# %% [markdown]
# # Set
