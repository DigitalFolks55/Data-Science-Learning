# %% [markdown]
# <style>
# .jp-Notebook h1, .jp-Notebook h2, .jp-Notebook h3 { letter-spacing: 0; }
# .hero {
#   padding: 14px 14px;
#   border-radius: 14px;
#   color: #ffffff;
#   background: #323232;
#   box-shadow: 0 8px 20px rgba(36, 76, 90, 0.14);
# }
# .hero h1 { margin: 0 0 8px 0; font-size: 2.4rem; }
# .hero p { margin: 6px 0; font-size: 1.05rem; }
# .hero p:last-child { margin-bottom: 0; }
# .badge {
#   display: inline-block;
#   padding: 4px 10px;
#   border-radius: 999px;
#   background: rgba(255, 255, 255, 0.22);
#   font-weight: 700;
#   margin-bottom: 10px;
# }
# .note {
#   padding: 10px 12px;
#   border-left: 5px solid #777;
#   background: #f6f6f6;
#   border-radius: 8px;
# }
# </style>
#
# <div class="hero">
#   <div class="badge">Notebook Template</div>
#   <h1>Project Title</h1>
#   <p>A reusable notebook structure for Python, data science, and model development work.</p>
#   <p><strong>Notebook goal:</strong> Replace this line with the main objective, expected outcome, and success criteria.</p>
# </div>
# <div style="height: 8px;"></div>

# %% [markdown]
# # Development Roadmap
#
# Use this notebook as a consistent starting point for future work.
#
# | Part | Section | Purpose |
# |---|---|---|
# | 1 | Context | Define the problem, objective, assumptions, and constraints |
# | 2 | Setup | Import libraries, configure paths, and set notebook options |
# | 3 | Data | Load, inspect, clean, and validate source data |
# | 4 | Exploration | Summarize patterns, quality issues, and useful relationships |
# | 5 | Development | Build reusable functions, analysis logic, features, or models |
# | 6 | Exercises | Knowledge test |
#
# <div class="note"><strong>Before starting:</strong> Update the title, goal, owner, date, and project-specific sections.</div>

# %% [markdown]
# ---

# %% [markdown]
# # 1. Context
#
# ## Problem Statement
#
# Describe the problem or question this notebook addresses.
#
# ## Objective
#
# State the target outcome in one or two sentences.
#
# ## Success Criteria
#
# | Criteria | Target | Notes |
# |---|---|---|
# | Accuracy / quality | TBD | Replace with a measurable target |
# | Runtime | TBD | Replace with an acceptable runtime |
# | Deliverable | TBD | Replace with expected output |
#
# ## Assumptions And Constraints
#
# - Assumption 1
# - Assumption 2
# - Constraint 1

# %% [markdown]
# ---

# %% [markdown]
# # 2. Setup

# %%
# Standard library
from pathlib import Path

# Third-party libraries
import numpy as np
import pandas as pd

# Notebook options
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.4f}".format)

# Project paths
PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
OUTPUT_DIR = PROJECT_ROOT / "outputs"

print("Project root:", PROJECT_ROOT)

# Press shift+enter to run the code

# %%
# Reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# Press shift+enter to run the code

# %% [markdown]
# ---

# %% [markdown]
# # 3. Data
#
# ## Data Sources
#
# | Source | Location | Description |
# |---|---|---|
# | TBD | TBD | TBD |

# %%
# Example: load a CSV file
# file_path = DATA_DIR / "input.csv"
# df = pd.read_csv(file_path)
# df.head()

# Press shift+enter to run the code

# %%
# Basic inspection checklist
# display(df.head())
# display(df.info())
# display(df.describe(include="all"))
# display(df.isna().sum().sort_values(ascending=False))

# Press shift+enter to run the code

# %% [markdown]
# ---

# %% [markdown]
# # 4. Exploration
#
# Use this section to understand distributions, relationships, missing values, outliers, and data quality issues.

# %%
# Exploration workspace
# Replace this cell with project-specific summaries, tables, or charts.

# Press shift+enter to run the code

# %% [markdown]
# ## Exploration Notes
#
# | Finding | Evidence | Action |
# |---|---|---|
# | TBD | TBD | TBD |

# %% [markdown]
# ---

# %% [markdown]
# # 5. Development

# %%
# Define reusable helper functions here.
def clean_column_names(dataframe):
    """Return a copy of a DataFrame with normalized column names."""
    cleaned = dataframe.copy()
    cleaned.columns = (
        cleaned.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_", regex=False)
    )
    return cleaned

# Press shift+enter to run the code

# %%
# Main development workspace
# Replace this cell with feature engineering, analysis, modeling, or utility logic.

# Press shift+enter to run the code

# %% [markdown]
# ---

# %% [markdown]
# # 6. Exercises
#
# Provide pracitce problems for knowledge check and prepare answers.

# %%
# Exercise 1: Define a function called greet that accepts name and returns "Hello, {name}!".

# Write your code here

# Press shift+enter to run the code

# %% [markdown]
# ## Exercise Answers
#
# Followings are examples of answers.

# %% [markdown]
# ---

# %% [markdown]
# # 7. Key Terms

# %% [markdown]
# | Term | Meaning |
# |---|---|
# | keyword | Explanations |

# %% [markdown]
# # 8. Wrap-Up
# Congratulations! You have finished the ... session.
#
# Here is what we have learned:
#
# | Section | What you learned |
# |---|---|
# | Context | Define the problem, objective, assumptions, and constraints |
# | Setup | Import libraries, configure paths, and set notebook options |
# | Data | Load, inspect, clean, and validate source data |
# | Exploration | Summarize patterns, quality issues, and useful relationships |
# | Development | Build reusable functions, analysis logic, features, or models |
# | Exercises | Knowledge test |
# * Add more contents
#
#
# Remember these core ideas:
#
# - HIghlights key learnings
#
# ⚠️ <strong>Exit ticket:</strong> Tip

# %% [markdown]
# © Training material was developed by dfolks.
# | Date | Log |
# |---|---|
# | May-2026 | 1st version |
